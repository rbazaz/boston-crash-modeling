# %% [markdown]
# * Distribution by time
#     * 7-8 AM and 5-6 PM have most traffic
#     * 2-3 AM has the least traffic

# %%
from IPython.display import Image
Image(filename='distribution_by_hours.png')

# %% [markdown]
# * Distribution by Place
#     * Most popular is 464 Huntington Ave-Roxbury
#     * Least popular is 10 Dungarven-Rd West-Roxbury

# %%
Image(filename='distribution_by_place.png')

# %%
Image(filename="distribution_across_vehicles.png")

# %%
Image(filename="distribution_of_cars_across_hours.png")

# %%
Image(filename="distribution_of_cars_across_neighborhoods.png")
